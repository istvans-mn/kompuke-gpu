# %% [markdown]
# # This is my notebook

# %% [markdown]
# 1. This
# 2. is
# 3. an
# 4. ordered
# 5. list
#
# * And this
# * is an
# * unordered list

# %% [markdown]
# Some famous formula: $E=mc^2$
#
# And a fraction: $\frac{1}{2}$

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("5pWseG4kVXo")

# %%
x = [1,2,3,4,5,6,7,8,9]
y = [4,7,3,6,4,6,8,3,2]

from matplotlib import pyplot as plt
# test
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-369e543e56c3> in <module>
#       2 y = [4,7,3,6,4,6,8,3,2]
#       3
# ----> 4 from matplotlib import pyplot as plt
#       5 # test
#       6 plt.plot(x,y)
#
# ModuleNotFoundError: No module named 'matplotlib'
